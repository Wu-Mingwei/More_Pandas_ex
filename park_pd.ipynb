# %%
import pandas as pd
import numpy as np 
import scipy
from scipy.stats import norm

# %%
dataset= pd.read_csv(r"C:\Users\wming\OneDrive\Desktop\kaggle\interview\pandas\parks.csv", index_col= ['Park Code'])
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#                         Park Name State   Acres  Latitude  Longitude
# Park Code
# ACAD         Acadia National Park    ME   47390     44.35     -68.21
# ARCH         Arches National Park    UT   76519     38.68    -109.57
# BADL       Badlands National Park    SD  242756     43.75    -102.50
# BIBE       Big Bend National Park    TX  801163     29.25    -103.25
# BISC       Biscayne National Park    FL  172924     25.65     -80.08

# %%
df.describe()
# Out:
#               Acres   Latitude   Longitude
# count  5.600000e+01  56.000000   56.000000
# mean   9.279291e+05  41.233929 -113.234821
# std    1.709258e+06  10.908831   22.440287
# min    5.550000e+03  19.380000 -159.280000
# 25%    6.901050e+04  35.527500 -121.570000
# 50%    2.387645e+05  38.550000 -110.985000
# 75%    8.173602e+05  46.880000 -103.400000
# max    8.323148e+06  67.780000  -68.210000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, ACAD to ZION
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Name  56 non-null     object
#  1   State      56 non-null     object
#  2   Acres      56 non-null     int64
#  3   Latitude   56 non-null     float64
#  4   Longitude  56 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.6+ KB

# %%
df.isna().sum()
df.tail()
# Out:
#                                                 Park Name       State  \
# Park Code
# WICA                              Wind Cave National Park          SD
# WRST       Wrangell - St Elias National Park and Preserve          AK
# YELL                            Yellowstone National Park  WY, MT, ID
# YOSE                               Yosemite National Park          CA
# ZION                                   Zion National Park          UT
#
#              Acres  Latitude  Longitude
# Park Code
# WICA         28295     43.57    -103.48
# WRST       8323148     61.00    -142.00
# YELL       2219791     44.60    -110.50
# YOSE        761266     37.83    -119.50
# ZION        146598     37.30    -113.05

# %%
df.groupby('Park Code').sum().sort_index(ascending=True).head()
# Out:
#                         Park Name State   Acres  Latitude  Longitude
# Park Code
# ACAD         Acadia National Park    ME   47390     44.35     -68.21
# ARCH         Arches National Park    UT   76519     38.68    -109.57
# BADL       Badlands National Park    SD  242756     43.75    -102.50
# BIBE       Big Bend National Park    TX  801163     29.25    -103.25
# BISC       Biscayne National Park    FL  172924     25.65     -80.08

# %%
df.iloc[2]
# Out:
# Park Name    Badlands National Park
# State                            SD
# Acres                        242756
# Latitude                      43.75
# Longitude                    -102.5
# Name: BADL, dtype: object

# %%
df.loc['ZION']
# Out:
# Park Name    Zion National Park
# State                        UT
# Acres                    146598
# Latitude                   37.3
# Longitude               -113.05
# Name: ZION, dtype: object

# %%
df.iloc[[2,3,0]]
# Out:
#                         Park Name State   Acres  Latitude  Longitude
# Park Code
# BADL       Badlands National Park    SD  242756     43.75    -102.50
# BIBE       Big Bend National Park    TX  801163     29.25    -103.25
# ACAD         Acadia National Park    ME   47390     44.35     -68.21

# %%
df.iloc[[2,3,6]]
# Out:
#                             Park Name State   Acres  Latitude  Longitude
# Park Code
# BADL           Badlands National Park    SD  242756     43.75    -102.50
# BIBE           Big Bend National Park    TX  801163     29.25    -103.25
# BRCA       Bryce Canyon National Park    UT   35835     37.57    -112.18

# %%
df[:2]
# Out:
#                       Park Name State  Acres  Latitude  Longitude
# Park Code
# ACAD       Acadia National Park    ME  47390     44.35     -68.21
# ARCH       Arches National Park    UT  76519     38.68    -109.57

# %%
df[2:6]
# Out:
#                                             Park Name State   Acres  Latitude  \
# Park Code
# BADL                           Badlands National Park    SD  242756     43.75
# BIBE                           Big Bend National Park    TX  801163     29.25
# BISC                           Biscayne National Park    FL  172924     25.65
# BLCA       Black Canyon of the Gunnison National Park    CO   32950     38.57
#
#            Longitude
# Park Code
# BADL         -102.50
# BIBE         -103.25
# BISC          -80.08
# BLCA         -107.72

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
print(df.columns)
# Out:
# Index(['park_name', 'state', 'acres', 'latitude', 'longitude'], dtype='object')

# %%
df[['state', 'acres']][2:6]
# Out:
#           state   acres
# Park Code
# BADL         SD  242756
# BIBE         TX  801163
# BISC         FL  172924
# BLCA         CO   32950

# %%
df.state.iloc[2:6]
# Out:
# Park Code
# BADL    SD
# BIBE    TX
# BISC    FL
# BLCA    CO
# Name: state, dtype: object

# %%
df[(df.latitude > 60) | (df.acres > 10**6)]
# Out:
#                                                 park_name       state  \
# Park Code
# DENA                    Denali National Park and Preserve          AK
# DEVA                           Death Valley National Park      CA, NV
# EVER                             Everglades National Park          FL
# GAAR       Gates Of The Arctic National Park and Preserve          AK
# GLAC                                Glacier National Park          MT
# GLBA               Glacier Bay National Park and Preserve          AK
# GRCA                           Grand Canyon National Park          AZ
# KATM                    Katmai National Park and Preserve          AK
# KOVA                           Kobuk Valley National Park          AK
# LACL                Lake Clark National Park and Preserve          AK
# WRST       Wrangell - St Elias National Park and Preserve          AK
# YELL                            Yellowstone National Park  WY, MT, ID
#
#              acres  latitude  longitude
# ...

# %%
df[(df.park_name == 'Denali National Park and Preserve') & (df.state == 'AK')]
# Out:
#                                    park_name state    acres  latitude  \
# Park Code
# DENA       Denali National Park and Preserve    AK  3372402     63.33
#
#            longitude
# Park Code
# DENA          -150.5

# %%
len3 = df[df['park_name'].str.split().apply(lambda x: len(x) == 3)].head(3)
len4 = df[df['park_name'].str.split().apply(lambda x: len(x) == 4)].head(3)
print(f"len3:{len3}")
print(f"len4: {len4}")
# Out:
# len3:                        park_name state   acres  latitude  longitude
# Park Code
# ACAD         Acadia National Park    ME   47390     44.35     -68.21
# ARCH         Arches National Park    UT   76519     38.68    -109.57
# BADL       Badlands National Park    SD  242756     43.75    -102.50
# len4:                             park_name state   acres  latitude  longitude
# Park Code
# BIBE           Big Bend National Park    TX  801163     29.25    -103.25
# BRCA       Bryce Canyon National Park    UT   35835     37.57    -112.18
# CARE       Capitol Reef National Park    UT  241904     38.20    -111.17

# %%
WA_CA =df[df.state.isin(['WA', 'CA'])].tail()
Not_WA_CA = df[~df.state.isin(['WA','CA'])].tail()
print(f"state in WA CA: {WA_CA}")
print(f"not in WA CA: {Not_WA_CA}")
# Out:
# state in WA CA:                                          park_name state   acres  latitude  \
# Park Code
# OLYM                         Olympic National Park    WA  922651     47.97
# PINN                       Pinnacles National Park    CA   26606     36.48
# REDW                         Redwood National Park    CA  112512     41.30
# SEKI       Sequoia and Kings Canyon National Parks    CA  865952     36.43
# YOSE                        Yosemite National Park    CA  761266     37.83
#
#            longitude
# Park Code
# OLYM         -123.50
# PINN         -121.16
# REDW         -124.00
# SEKI         -118.68
# YOSE         -119.50
# not in WA CA:                                                 park_name       state  \
# Park Code
# VOYA                              Voyageurs National Park          MN
# WICA                              Wind Cave National Park          SD
# WRST       Wrangell - St Elias National Park and Preserve          AK
# ...

# %%
df[['acres', 'latitude']][df.acres == df['acres'].max()]
# Out:
#              acres  latitude
# Park Code
# WRST       8323148      61.0

# %%
df['acres'].max()
# Out:
# np.int64(8323148)

# %%
state = df.groupby('state')
total_state = state.get_group('CA')
total_state_latitude = total_state['acres'].max()
print(f"group state:{total_state}")
print(f"max latitude: {total_state_latitude}")
# Out:
# group state:                                         park_name state   acres  latitude  \
# Park Code
# CHIS                 Channel Islands National Park    CA  249561     34.01
# JOTR                     Joshua Tree National Park    CA  789745     33.79
# LAVO                 Lassen Volcanic National Park    CA  106372     40.49
# PINN                       Pinnacles National Park    CA   26606     36.48
# REDW                         Redwood National Park    CA  112512     41.30
# SEKI       Sequoia and Kings Canyon National Parks    CA  865952     36.43
# YOSE                        Yosemite National Park    CA  761266     37.83
#
#            longitude
# Park Code
# CHIS         -119.42
# JOTR         -115.90
# LAVO         -121.51
# PINN         -121.16
# REDW         -124.00
# SEKI         -118.68
# YOSE         -119.50
# max latitude: 865952

# %%
df['state'].value_counts()
# Out:
# state
# AK            8
# CA            7
# UT            5
# CO            4
# FL            3
# AZ            3
# WA            3
# HI            2
# SD            2
# TX            2
# ME            1
# OH            1
# OR            1
# SC            1
# NM            1
# NV            1
# MT            1
# TN, NC        1
# CA, NV        1
# WY            1
# AR            1
# MI            1
# KY            1
# VA            1
# ND            1
# MN            1
# WY, MT, ID    1
# Name: count, dtype: int64

# %%
df_state = df.sort_values(by= ['state' , 'park_name'], ascending= True)
print(f"df_state sort : {df_state}")
# Out:
# df_state sort :                                                 park_name       state  \
# Park Code
# DENA                    Denali National Park and Preserve          AK
# GAAR       Gates Of The Arctic National Park and Preserve          AK
# GLBA               Glacier Bay National Park and Preserve          AK
# KATM                    Katmai National Park and Preserve          AK
# KEFJ                           Kenai Fjords National Park          AK
# KOVA                           Kobuk Valley National Park          AK
# LACL                Lake Clark National Park and Preserve          AK
# WRST       Wrangell - St Elias National Park and Preserve          AK
# HOSP                            Hot Springs National Park          AR
# GRCA                           Grand Canyon National Park          AZ
# PEFO                       Petrified Forest National Park          AZ
# SAGU                                Saguaro National Park          AZ
# ...
